# %% [markdown]
# <a href="https://colab.research.google.com/github/shrey2023p/shrey/blob/main/Shrey_Python.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
class Node:
    def __init__(self, data, level, fval):
        self.data = data
        self.level = level
        self.fval = fval

    def generate_child(self):
        x, y = self.find(self.data, '_')
        val_list = [[x, y - 1], [x, y + 1], [x - 1, y], [x + 1, y]]
        children = []
        for i in val_list:
            child = self.shuffle(self.data, x, y, i[0], i[1])
            if child is not None:
                child_node = Node(child, self.level + 1, 0)
                children.append(child_node)
        return children

    def shuffle(self, puz, x1, y1, x2, y2):
        if 0 <= x2 < len(self.data) and 0 <= y2 < len(self.data):
            temp_puz = self.copy(puz)
            temp_puz[x1][y1], temp_puz[x2][y2] = temp_puz[x2][y2], temp_puz[x1][y1]
            return temp_puz
        return None

    def copy(self, root):
        return [row[:] for row in root]

    def find(self, puz, x):
        for i in range(len(self.data)):
            for j in range(len(self.data)):
                if puz[i][j] == x:
                    return i, j


class Puzzle:
    def __init__(self, size):
        self.n = size
        self.open = []
        self.closed = []

    def input_matrix(self, prompt):
        print(prompt)
        matrix = []
        for i in range(self.n):
            row = input(f"Enter row {i+1} (space-separated, use '_' for blank): ").split()
            matrix.append(row)
        return matrix

    def f(self, start, goal):
        return self.h(start.data, goal) + start.level

    def h(self, start, goal):
        temp = 0
        for i in range(self.n):
            for j in range(self.n):
                if start[i][j] != goal[i][j] and start[i][j] != '_':
                    temp += 1
        return temp

    def process(self):
        start = self.input_matrix("Enter the START state:")
        goal = self.input_matrix("Enter the GOAL state:")

        start_node = Node(start, 0, 0)
        start_node.fval = self.f(start_node, goal)

        self.open.append(start_node)

        while True:
            cur = self.open[0]

            print("\nCurrent State (Level {}):".format(cur.level))
            for i in cur.data:
                print(" ".join(i))

            if self.h(cur.data, goal) == 0:
                print("\nGoal state reached!")
                break

            for i in cur.generate_child():
                i.fval = self.f(i, goal)
                self.open.append(i)

            self.closed.append(cur)
            del self.open[0]

            self.open.sort(key=lambda x: x.fval)


if __name__ == "__main__":
    print("8-Puzzle Solver using A* Search\n")
    puzzle = Puzzle(3)
    puzzle.process()
# Out:
# 8-Puzzle Solver using A* Search
#
# Enter the START state:
# Enter row 1 (space-separated, use '_' for blank): 2 8 3
# Enter row 2 (space-separated, use '_' for blank): 1 6 4
# Enter row 3 (space-separated, use '_' for blank): 7 _  5
# Enter the GOAL state:
# Enter row 1 (space-separated, use '_' for blank): 1 2 3
# Enter row 2 (space-separated, use '_' for blank): 8 _ 4
# Enter row 3 (space-separated, use '_' for blank): 7 6 5
#
# Current State (Level 0):
# 2 8 3
# 1 6 4
# 7 _ 5
#
# Current State (Level 1):
# 2 8 3
# 1 _ 4
# 7 6 5
#
# Current State (Level 2):
# 2 8 3
# _ 1 4
# 7 6 5
#
# Current State (Level 2):
# 2 _ 3
# 1 8 4
# 7 6 5
#
# Current State (Level 3):
# _ 2 3
# 1 8 4
# 7 6 5
#
# Current State (Level 4):
# 1 2 3
# _ 8 4
# 7 6 5
#
# Current State (Level 5):
# 1 2 3
# 8 _ 4
# 7 6 5
#
# Goal state reached!
